# %%
import os
import scipy
import numpy as np
import pandas as pd
import sys
import multivelo as mv
import scanpy as sc
import scvelo as scv
import matplotlib.pyplot as plt
import requests

# %%
scv.settings.verbosity = 3
scv.settings.presenter_view = True
scv.set_figure_params('scvelo')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
np.set_printoptions(suppress=True)

# %%
adataSuperCellHSPC = sc.read_h5ad("../../output/multiomicVelocity/humanHSPC/SuperCellPostPro/multivelo_result.h5ad")

# %%
scv.pl.umap(adataSuperCellHSPC, color='leiden',palette= "tab20")

# %%
mv.velocity_embedding_stream(adataSuperCellHSPC, basis='umap', color='leiden', show=True)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.scatter(adataSuperCellHSPC, color='latent_time', color_map='gnuplot', size=80)

# %%
adataSuperCellHSPC
# Out:
# AnnData object with n_obs × n_vars = 1160 × 997
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'orig.ident_purity', 'phase', 'phase_purity', 'leiden', 'leiden_purity', 'size', 'velo_s_norm_self_transition', 'root_cells', 'end_points', 'velo_s_norm_pseudotime', 'latent_time'
#     var: 'fit_alpha_c', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_sw1', 'fit_t_sw2', 'fit_t_sw3', 'fit_scale_cc', 'fit_rescale_c', 'fit_rescale_u', 'fit_alignment_scaling', 'fit_model', 'fit_direction', 'fit_loss', 'fit_likelihood', 'fit_likelihood_c', 'fit_ssd_c', 'fit_var_c', 'fit_c0', 'fit_u0', 'fit_s0', 'fit_anchor_min_idx', 'fit_anchor_max_idx', 'fit_anchor_velo_min_idx', 'fit_anchor_velo_max_idx', 'velo_s_genes', 'velo_u_genes', 'velo_chrom_genes', 'velo_s_norm_genes'
#     uns: 'neighbors', 'pca', 'velo_chrom_params', 'velo_s_norm_graph', 'velo_s_norm_graph_neg', 'velo_s_norm_params', 'velo_s_params', 'velo_u_params', 'leiden_colors'
#     obsm: 'X_pca', 'X_umap', 'velo_s_norm_umap'
# ...

# %%
adataSubHSPC = sc.read_h5ad("../../output/multiomicVelocity/humanHSPC/Subsampling/multivelo_result.h5ad")

# %%
adataSubHSPC
# Out:
# AnnData object with n_obs × n_vars = 1160 × 926
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'n_counts', 'n_genes_by_counts', 'total_counts', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'S_score', 'G2M_score', 'phase', 'fraction_u', 'leiden', 'root_prediction', 'total_s', 'total_u', 'total_Ms', 'total_Mu', 'nCount_aggATAC', 'velo_s_norm_self_transition', 'root_cells', 'end_points', 'velo_s_norm_pseudotime', 'latent_time'
#     var: 'fit_alpha_c', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_sw1', 'fit_t_sw2', 'fit_t_sw3', 'fit_scale_cc', 'fit_rescale_c', 'fit_rescale_u', 'fit_alignment_scaling', 'fit_model', 'fit_direction', 'fit_loss', 'fit_likelihood', 'fit_likelihood_c', 'fit_ssd_c', 'fit_var_c', 'fit_c0', 'fit_u0', 'fit_s0', 'fit_anchor_min_idx', 'fit_anchor_max_idx', 'fit_anchor_velo_min_idx', 'fit_anchor_velo_max_idx', 'velo_s_genes', 'velo_u_genes', 'velo_chrom_genes', 'velo_s_norm_genes'
# ...

# %%
scv.pl.umap(adataSubHSPC, color='leiden',palette= "tab20")

# %%
mv.velocity_embedding_stream(adataSubHSPC, basis='umap', color='leiden', show=True)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.scatter(adataSubHSPC, color='latent_time', color_map='gnuplot', size=80)

# %%
adataHSPC = sc.read_h5ad("../../output/multiomicVelocity/humanHSPC/singleCell/multivelo_result.h5ad")

# %%
scv.pl.umap(adataHSPC, color='leiden',palette= "tab20")

# %%
mv.velocity_embedding_stream(adataHSPC, basis='umap', color='leiden', show=True)
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.scatter(adataHSPC, color='latent_time', color_map='gnuplot', size=80)

# %%
adataSuperCellBrain = sc.read_h5ad("../../output/multiomicVelocity/humanBrain/SuperCellPostPro/multivelo_result.h5ad")

# %%
adataSuperCellBrain
# Out:
# AnnData object with n_obs × n_vars = 469 × 898
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'orig.ident_purity', 'cluster', 'cluster_purity', 'batch', 'batch_purity', 'size', 'velo_s_norm_self_transition', 'root_cells', 'end_points', 'velo_s_norm_pseudotime', 'latent_time'
#     var: 'fit_alpha_c', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_sw1', 'fit_t_sw2', 'fit_t_sw3', 'fit_scale_cc', 'fit_rescale_c', 'fit_rescale_u', 'fit_alignment_scaling', 'fit_model', 'fit_direction', 'fit_loss', 'fit_likelihood', 'fit_likelihood_c', 'fit_ssd_c', 'fit_var_c', 'fit_c0', 'fit_u0', 'fit_s0', 'fit_anchor_min_idx', 'fit_anchor_max_idx', 'fit_anchor_velo_min_idx', 'fit_anchor_velo_max_idx', 'velo_s_genes', 'velo_u_genes', 'velo_chrom_genes', 'velo_s_norm_genes'
#     uns: 'neighbors', 'pca', 'velo_chrom_params', 'velo_s_norm_graph', 'velo_s_norm_graph_neg', 'velo_s_norm_params', 'velo_s_params', 'velo_u_params', 'cluster_colors'
#     obsm: 'X_pca', 'X_umap', 'velo_s_norm_umap'
# ...

# %%
scv.pl.umap(adataSuperCellBrain, color='cluster',palette= "tab20")

# %%
mv.velocity_embedding_stream(adataSuperCellBrain, basis='umap', color='cluster', show=True)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.scatter(adataSuperCellBrain, color='latent_time', color_map='gnuplot', size=80)

# %%
adataSubSmpBrain = sc.read_h5ad("../../output/multiomicVelocity/humanBrain/Subsampling/multivelo_result.h5ad")

# %%
scv.pl.umap(adataSubSmpBrain, color='cluster',palette= "tab20")

# %%
mv.velocity_embedding_stream(adataSubSmpBrain, basis='umap', color='cluster', show=True)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.scatter(adataSubSmpBrain, color='latent_time', color_map='gnuplot', size=80)

# %%
adataBrain = sc.read_h5ad("../../output/multiomicVelocity/humanBrain/singleCell/multivelo_result.h5ad")

# %%
scv.pl.umap(adataBrain, color='cluster',palette= "tab20")

# %%
mv.velocity_embedding_stream(adataBrain, basis='umap', color='cluster', show=True)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.scatter(adataBrain, color='latent_time', color_map='gnuplot', size=80)
